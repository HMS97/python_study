# %% [markdown]
# Requests

# %%
import requests
from PIL import Image
from io import BytesIO
import json


#r = requests.get('https://api.github.com/events',stream = True)
url = 'https://api.github.com/some/endpoint'
headers = {'user-agent':'my-app/0.0.1'}
r = requests.get(url,headers = headers)

print(r.url)
print(r.text)
print(r.encoding)
print(r.content)
print(r.json())
#print(r.raise_for_status())
print(r.raw)
print(r.raw.read(10))

#i = Image.open(BytesIO(r.content))

payload = {'key1':'value1','key2':['value2','value3']}
r = requests.get('https://httpbin.org/get',params = payload)
print(r.url)

url = 'https://api.github.com/some/endpoint'
payload = {'some':'data'}
#r = requests.post(url,data = json.dumps(payload))
r = requests.post(url,json = payload)
print(r.url)
print(r.text)

r = requests.get('https://httpbin.org/get')
print(r.status_code)
print(r.status_code == requests.codes.ok)


r = requests.post('https://httpbin.org/post',data = {'key':'value'})
print(r.url)
print(r.text)

r = requests.post('https://httpbin.org/post',params = payload)
print(r.url)
print(r.text)

# url = 'http://httpbin.org/post'
# files = {'file':('hancheng.csv',open('hancheng.csv','rb'),'application/vnd.ms-excel',{'Expires':'0'})}
# r = requests.post(url,files = files)
# print(r.text)
bad_r = requests.get('https://httpbin.org/status/404')
print(bad_r.status_code)
#print(bad_r.raise_for_status())
print(r.headers)

url = 'http://example.com/some/cookie/setting/url'
cookies = dict(cookies_are = 'working')
r = requests.get(url,cookies = cookies)
print(r.text)

r = requests.get('http://github.com')
print(r.url)
print(r.status_code)
print(r.history)

r = requests.get('http://github.com',allow_redirects = False)
print(r.status_code)
print(r.history)

requests.get('http://github.com',timeout = 0.001)
# Out:
# https://api.github.com/some/endpoint
# {"message":"Not Found","documentation_url":"https://developer.github.com/v3"}
# utf-8
# b'{"message":"Not Found","documentation_url":"https://developer.github.com/v3"}'
# {'message': 'Not Found', 'documentation_url': 'https://developer.github.com/v3'}
# <urllib3.response.HTTPResponse object at 0x00000148AE946240>
# b''
# https://httpbin.org/get?key1=value1&key2=value2&key2=value3
# https://api.github.com/some/endpoint
# {"message":"Not Found","documentation_url":"https://developer.github.com/v3"}
# 200
# True
# https://httpbin.org/post
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key": "value"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "9",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.19.1"
#   },
#   "json": null,
#   "origin": "1.85.61.28, 1.85.61.28",
#   "url": "https://httpbin.org/post"
# }
#
# https://httpbin.org/post?some=data
# {
#   "args": {
#     "some": "data"
#   },
#   "data": "",
#   "files": {},
#   "form": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "0",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.19.1"
#   },
#   "json": null,
#   "origin": "1.85.61.28, 1.85.61.28",
#   "url": "https://httpbin.org/post?some=data"
# }
#
# 404
# {'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Origin': '*', 'Content-Encoding': 'gzip', 'Content-Type': 'application/json', 'Date': 'Sat, 06 Apr 2019 04:12:22 GMT', 'Server': 'nginx', 'Content-Length': '237', 'Connection': 'keep-alive'}
# <!doctype html>
# <html>
# <head>
#     <title>Example Domain</title>
#
#     <meta charset="utf-8" />
#     <meta http-equiv="Content-type" content="text/html; charset=utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 50px;
#         background-color: #fff;
#         border-radius: 1em;
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         body {
#             background-color: #fff;
#         }
#         div {
#             width: auto;
#             margin: 0 auto;
#             border-radius: 0;
#             padding: 1em;
#         }
#     }
#     </style>
# </head>
#
# <body>
# <div>
#     <h1>Example Domain</h1>
#     <p>This domain is established to be used for illustrative examples in documents. You may use this
#     domain in examples without prior coordination or asking for permission.</p>
#     <p><a href="http://www.iana.org/domains/example">More information...</a></p>
# </div>
# </body>
# </html>
#
# https://github.com/
# 200
# [<Response [301]>]
# 301
# []
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# D:\python3.7\Anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#
# D:\python3.7\Anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      78     if err is not None:
# ---> 79         raise err
#      80
#
# D:\python3.7\Anaconda\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      68                 sock.bind(source_address)
# ---> 69             sock.connect(sa)
#      70             return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# D:\python3.7\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# D:\python3.7\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# D:\python3.7\Anaconda\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# D:\python3.7\Anaconda\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# D:\python3.7\Anaconda\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# D:\python3.7\Anaconda\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# D:\python3.7\Anaconda\lib\http\client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# D:\python3.7\Anaconda\lib\site-packages\urllib3\connection.py in connect(self)
#     195     def connect(self):
# --> 196         conn = self._new_conn()
#     197         self._prepare_conn(conn)
#
# D:\python3.7\Anaconda\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     175                 self, "Connection to %s timed out. (connect timeout=%s)" %
# --> 176                 (self.host, self.timeout))
#     177
#
# ConnectTimeoutError: (<urllib3.connection.HTTPConnection object at 0x00000148AE94FD30>, 'Connection to github.com timed out. (connect timeout=0.001)')
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# D:\python3.7\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#
# D:\python3.7\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# D:\python3.7\Anaconda\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPConnectionPool(host='github.com', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x00000148AE94FD30>, 'Connection to github.com timed out. (connect timeout=0.001)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# <ipython-input-36-0608e5bfbaf3> in <module>()
#      68 print(r.history)
#      69
# ---> 70 requests.get('http://github.com',timeout = 0.001)
#
# D:\python3.7\Anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# D:\python3.7\Anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# D:\python3.7\Anaconda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# D:\python3.7\Anaconda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# D:\python3.7\Anaconda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     499                 # TODO: Remove this in 3.0.0: see #2811
#     500                 if not isinstance(e.reason, NewConnectionError):
# --> 501                     raise ConnectTimeout(e, request=request)
#     502
#     503             if isinstance(e.reason, ResponseError):
#
# ConnectTimeout: HTTPConnectionPool(host='github.com', port=80): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x00000148AE94FD30>, 'Connection to github.com timed out. (connect timeout=0.001)'))
