# %%
# -*- coding: utf-8 -*-

import urllib.request
import json

#定义要爬取的用户的微博ID
id = '5644764907'
# id = '1259110474'

#设置代理IP
proxy_addr="122.241.72.191:808"

#定义页面打开函数
def use_proxy(url,proxy_addr):
    req = urllib.request.Request(url)
    req.add_header("User-Agent","Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/49.0.2623.221 Safari/537.36 SE 2.X MetaSr 1.0")
    proxy = urllib.request.ProxyHandler({'http':proxy_addr})
    opener = urllib.request.build_opener(proxy,urllib.request.HTTPHandler)
    urllib.request.install_opener(opener)
    data = urllib.request.urlopen(req).read().decode('utf-8','ignore')
    return data

#获取微博主页的containerid，爬取微博内容时需要此id
def get_containerid(url):
    data = use_proxy(url,proxy_addr)
    content = json.loads(data).get('data')
    for data in content.get('tabsInfo').get('tabs'):
        if(data.get('tab_type') == 'weibo'):
            containerid = data.get('containerid')
    return containerid

#获取微博用户基本信息，如：微博昵称、微博地址、微博头像、关注人数、粉丝数、性别、等级等
def get_userInfo(id):
    url = 'https://m.weibo.cn/api/container/getIndex?type=uid&value='+id
    data = use_proxy(url,proxy_addr)
    content = json.loads(data).get('data')
    profile_image_url = content.get('userInfo').get('profile_image_url')
    description = content.get('userInfo').get('description')
    profile_url = content.get('userInfo').get('profile_url')
    verified = content.get('userInfo').get('verified')
    guanzhu = content.get('userInfo').get('follow_count')
    name = content.get('userInfo').get('screen_name')
    fensi = content.get('userInfo').get('followers_count')
    gender = content.get('userInfo').get('gender')
    urank = content.get('userInfo').get('urank')
    print("微博昵称：" + name + "\n" + "微博主页地址：" + profile_url + "\n" + "微博头像地址：" + profile_image_url + "\n" + "是否认证：" + str(verified)  + "\n" + "微博说明：" + description + "\n" + "关注人数：" + str(guanzhu) + "\n" + "粉丝数：" + str(fensi) + "\n" + "性别：" + gender + "n" + "微博等级：" + str(urank) + "\n")


#获取微博内容信息,并保存到文本中，内容包括：每条微博的内容、微博详情页面地址、点赞数、评论数、转发数等
def get_weibo(id,file):
    i = 1
    while True:
        url = 'https://m.weibo.cn/api/container/getIndex?type=uid&value=' + id
        weibo_url = 'https://m.weibo.cn/api/container/getIndex?type=uid&value=' + id + '&containerid=' + get_containerid(url) + '&page=' + str(i)
        try:
            data = use_proxy(weibo_url,proxy_addr)
            content = json.loads(data).get('data')
            cards = content.get('cards')
            if(len(cards) > 0):
                for j in range(len(cards)):
#                     print("-----正在爬取第"+str(i)+"页，第"+str(j)+"条微博------")
                    card_type = cards[j].get('card_type')
                    if(card_type == 9):
                        mblog = cards[j].get('mblog')
                        attitudes_count = mblog.get('attitudes_count')
                        comments_count = mblog.get('comments_count')
                        created_at = mblog.get('created_at')
                        reposts_count = mblog.get('reposts_count')
                        scheme = cards[j].get('scheme')
                        text = mblog.get('text')
                        with open(file,'a',encoding = 'utf-8') as fh:
                            fh.write("----第" + str(i) + "页，第" + str(j) + "条微博----" + "\n")
                            fh.write("微博地址：" + str(scheme) + "\n" + "发布时间：" + str(created_at) + "\n" + "微博内容：" + text + "\n" + "点赞数：" + str(attitudes_count) + "\n" + "评论数：" + str(comments_count) + "\n" + "转发数：" + str(reposts_count) + "\n")
                i += 1
            else:
                break
        except Exception as e:
            print(e)
            pass

if __name__=="__main__":
    file = id + ".txt"
    get_userInfo(id)
    get_weibo(id,file)
  
    
# txtpath=r'C:/Users/lenovo/1259110474.txt'
#-*- coding:utf-8 -*-
 
f = open('1259110474.txt', 'r',encoding='UTF-8')              
sourceInLines = f.readlines()  #按行读出文件内容
f.close()
new = []                                   #定义一个空列表，用来存储结果
for line in sourceInLines:
    temp1 = line.strip('\n')       #去掉每行最后的换行符'\n'
    temp2 = temp1.split(',')     #以','为标志，将每行分割成列表
    new.append(temp2)          #将上一步得到的列表添加到new中
     
print(new)
# Out:
# 微博昵称：火箭少女101_杨超越
# 微博主页地址：https://m.weibo.cn/u/5644764907?uid=5644764907&luicode=10000011&lfid=1005055644764907
# 微博头像地址：https://tvax4.sinaimg.cn/crop.0.0.1080.1080.180/006a0Rdhly8g0yt4blm2sj30u00u0n17.jpg
# 是否认证：True
# 微博说明：
# 关注人数：186
# 粉丝数：7663520
# 性别：fn微博等级：31
#
# [['----第1页，第0条微博----'], ['微博地址：https://m.weibo.cn/status/HnKxe4ZEf?mblogid=HnKxe4ZEf&luicode=10000011&lfid=1076031259110474'], ['发布时间：04-02'], ['微博内容：铭记英雄，一路走好<span class="url-icon"><img alt=[蜡烛] src="//h5.sinaimg.cn/m/emoticon/icon/others/o_lazhu-6209fc6e73.png" style="width:1em; height:1em;" /></span><span class="url-icon"><img alt=[蜡烛] src="//h5.sinaimg.cn/m/emoticon/icon/others/o_lazhu-6209fc6e73.png" style="width:1em; height:1em;" /></span><span class="url-icon"><img alt=[蜡烛] src="//h5.sinaimg.cn/m/emoticon/icon/others/o_lazhu-6209fc6e73.png" style="width:1em; height:1em;" /></span>'], ['点赞数：220861'], ['评论数：136693'], ['转发数：58212'], ['----第1页，第2条微博----'], ['微博地址：https://m.weibo.cn/status/Hn9x2zV9S?mblogid=Hn9x2zV9S&luicode=10000011&lfid=1076031259110474'], ['发布时间：03-29'], ['微博内容：<a  href="https://m.weibo.cn/search?containerid=231522type%3D1%26t%3D10%26q%3D%23%E7%94%B5%E8%A7%86%E5%89%A7%E7%9F%A5%E5%90%A6%E7%9F%A5%E5%90%A6%E5%BA%94%E6%98%AF%E7%BB%BF%E8%82%A5%E7%BA%A2%E7%98%A6%23&isnewpage=1&luicode=10000011&lfid=1076031259110474" data-hide=""><span class="surl-text">#电视剧知否知否应是绿肥红瘦#</span></a> 冬去春来，二刷精彩<span class="url-icon"><img alt=[喵喵] src="//h5.sinaimg.cn/m/emoticon/icon/others/d_miao-61fe2a7aaa.png" style="width:1em; height:1em;" /></span>'], ['点赞数：207841'], ['评论数：355447'], ['转发数：300111'], ['----第1页，第3条微博----'], ['微博地址：https://m.weibo.cn/status/HjmkiuJUl?mblogid=HjmkiuJUl&luicode=10000011&lfid=1076031259110474'], ['发布时间：03-04'], ['微博内容：宣个靠谱儿的<span class="url-icon"><img alt=[可爱] src="//h5.sinaimg.cn/m/emoticon/icon/default/d_keai-7a5bf88086.png" style="width:1em; height:1em;" /></span>“和”伙儿人报道！未来，让我们继续用简单的心做些不简单的事<span class="url-icon"><img alt=[握手] src="//h5.sinaimg.cn/m/emo